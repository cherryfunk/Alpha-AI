# %%
import pandas as pd

areas = [
    {'Name': 'Human (Hero)', 'Symbol': '��', 'Category': '10. TRANSCENDENCE'},
    {'Name': 'inf. Spirit', 'Symbol': '✨', 'Category': '10. TRANSCENDENCE'},
    {'Name': '13. Personality', 'Symbol': '🧑', 'Category': '09. HUMANITARIAN'},
    {'Name': '12. Person (Moral)', 'Symbol': '⚖️', 'Category': '09. HUMANITARIAN'},
    {'Name': '11. Conscience (Legal)', 'Symbol': '⚖️', 'Category': '09. HUMANITARIAN'},
    {'Name': '10. Self-Government', 'Symbol': '👑', 'Category': '08. DEVELOPMENT'},
    {'Name': '09. Organiser', 'Symbol': '📋', 'Category': '08. DEVELOPMENT'},
    {'Name': '08. Behavior', 'Symbol': '🎭', 'Category': '08. DEVELOPMENT'},
    {'Name': '07. Intellect', 'Symbol': '🧠', 'Category': '07. REFLECTION'},
    {'Name': '06. Mind', 'Symbol': '��', 'Category': '06. ESTEEM'},
    {'Name': '05. Social', 'Symbol': '👥', 'Category': '05. SOCIAL LIFE'},
    {'Name': 'x. Ego', 'Symbol': '⚛️', 'Category': '06. ESTEEM'},
    {'Name': '04. Soul', 'Symbol': '😄', 'Category': '04. EMOTIONAL'},
    {'Name': '03. Seeker', 'Symbol': '🔍', 'Category': '03. RESOURCE'},
    {'Name': '02. Body', 'Symbol': '💪', 'Category': '02. PHYSICAL'},
    {'Name': '01. Material', 'Symbol': '💎', 'Category': '01. BASIS'},
    {'Name': 'n. Life (Reproduction)', 'Symbol': '⚕️', 'Category': '05. SOCIAL LIFE'},
    {'Name': 'e. Consumer/Producer', 'Symbol': '🏭', 'Category': '03. RESOURCE'},
    {'Name': '-00. Home', 'Symbol': '��', 'Category': '01. BASIS'},
    {'Name': '-01. Death (Survival)', 'Symbol': '💀', 'Category': '04. EMOTIONAL'},
    {'Name': '-02. Technology', 'Symbol': '🛠️', 'Category': '03. RESOURCE'},
    {'Name': '-inf. Universe', 'Symbol': '🌌', 'Category': '03. RESOURCE'},
    {'Name': 'k. Time', 'Symbol': '⏰', 'Category': '08. DEVELOPMENT'},
    {'Name': 'j. Culture (Audio)', 'Symbol': '🎵', 'Category': '02. PHYSICAL'},
    {'Name': 'i*inf. Dream/Drug', 'Symbol': '💫', 'Category': '05. SOCIAL LIFE'},
    {'Name': 'i. Imagination', 'Symbol': '🎨', 'Category': '07. REFLECTION'},
    {'Name': '-k. Space', 'Symbol': '��', 'Category': '01. BASIS'},
    {'Name': '-j. Nature', 'Symbol': '��', 'Category': '01. BASIS'},
    {'Name': '-i*inf. Sleep', 'Symbol': '💤', 'Category': '10. TRANSCENDENCE'},
    {'Name': '-i. Reality', 'Symbol': '👁️', 'Category': '02. PHYSICAL'},
]

df = pd.DataFrame(areas)
df
# Out:
#                       Name Symbol           Category
# 0             Human (Hero)     ��  10. TRANSCENDENCE
# 1              inf. Spirit      ✨  10. TRANSCENDENCE
# 2          13. Personality      🧑   09. HUMANITARIAN
# 3       12. Person (Moral)     ⚖️   09. HUMANITARIAN
# 4   11. Conscience (Legal)     ⚖️   09. HUMANITARIAN
# 5      10. Self-Government      👑    08. DEVELOPMENT
# 6            09. Organiser      📋    08. DEVELOPMENT
# 7             08. Behavior      🎭    08. DEVELOPMENT
# 8            07. Intellect      🧠     07. REFLECTION
# 9                 06. Mind     ��         06. ESTEEM
# 10              05. Social      👥    05. SOCIAL LIFE
# 11                  x. Ego     ⚛️         06. ESTEEM
# 12                04. Soul      😄      04. EMOTIONAL
# 13              03. Seeker      🔍       03. RESOURCE
# 14                02. Body      💪       02. PHYSICAL
# 15            01. Material      💎          01. BASIS
# 16  n. Life (Reproduction)     ⚕️    05. SOCIAL LIFE
# ...
